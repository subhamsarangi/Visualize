# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('seaborn-darkgrid')

# %% [markdown]
# # Figure
# ### The Figure is the top-level container in this hierarchy. It is the overall window/page that everything is drawn on. You can have multiple independent figures and Figures can contain multiple Axes.
#
# Most plotting ocurs on an Axes. The axes is effectively the area that we plot data on and any ticks/labels/etc associated with it. Usually we'll set up an Axes with a call to subplot (which places Axes on a regular grid), so in most cases, Axes and Subplot are synonymous.
#
# Each Axes has an XAxis and a YAxis. These contain the ticks, tick locations, labels, etc. In this tutorial, we'll mostly control ticks, tick labels, and data limits through other mechanisms, so we won't touch the individual Axis part of things all that much. However, it is worth mentioning here to explain where the term Axes comes from.
#
# ### you can control the size of the figure through the figsize argument, which expects a tuple of (width, height) in inches.
#
# #### A really useful utility function is `figaspect`

# %%
# Twice as tall as it is wide:
fig = plt.figure(figsize=plt.figaspect(2.0))
plt.show()

# %% [markdown]
# # Axes
# All plotting is done with respect to an Axes. An Axes is made up of _Axis_ objects and many other things. An Axes object must belong to a Figure (and only one Figure). Most commands you will ever issue will be with respect to this Axes object.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Axes',
       ylabel='Y-Axis', xlabel='X-Axis')
plt.show()

# %% [markdown]
# Matplotlib's objects typically have lots of __"explicit setters"__, in other words, functions that start with set_something and control a particular option.
# We could have written the third line above as:
#
# ```python
# ax.set_xlim([0.5, 4.5])
# ax.set_ylim([-2, 8])
# ax.set_title('An Example Axes')
# ax.set_ylabel('Y-Axis')
# ax.set_xlabel('X-Axis')
# ```
# **Note** that the set method doesn't just apply to Axes; it applies to more-or-less all matplotlib objects.

# %% [markdown]
# ### let's focus on two plotting methods: plot and scatter.
# plot draws points with lines connecting them. scatter draws unconnected points, optionally scaled or colored by additional variables.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
plt.show()

# %% [markdown]
# ## Axes methods vs. pyplot
# Interestingly, just about all methods of an Axes object exist as a function in the pyplot module (and vice-versa). For example, when calling `plt.xlim(1, 10)`, pyplot calls `ax.set_xlim(1, 10)` on whichever Axes is "current".
# _Here is an equivalent version of the above example using just pyplot._
# ```python
# plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
# plt.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
# plt.xlim(0.5, 4.5)
# plt.show()
# ```

# %% [markdown]
# ## Multiple Axes
# We've mentioned before that a figure can have more than one Axes on it. If you want your axes to be on a regular grid system, then it's easiest to use plt.subplots(...) to create a figure and add the axes to it automatically.
# For example:
# ```python
#
# ```

# %%
fig, axes = plt.subplots(nrows=2, ncols=2) #a new figure and added 4 subplots
plt.show()

# %% [markdown]
# plt.subplots(...) created a new figure and added 4 subplots to it. The axes object that was returned is a 2D numpy object array. Each item in the array is one of the subplots. They're laid out as you see them on the figure.
#
# Therefore, when we want to work with one of these axes, **we can index the axes array and use that item's methods**.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
axes[0,0].set(title='Upper Left')
axes[0,1].set(title='Upper Right')
axes[1,0].set(title='Lower Left')
axes[1,1].set(title='Lower Right')

# To iterate over all items in a multidimensional numpy array, use the `flat` attribute
for ax in axes.flat:
    # Remove all xticks and yticks...
    ax.set(xticks=[], yticks=[])
    
plt.show()

# %% [markdown]
# One really nice thing about plt.subplots() is that when it's called with no arguments, it creates a new figure with a single subplot.
#
# Any time you see something like
#
# ```python
# fig = plt.figure()
# ax = fig.add_subplot(111)
# ```
# You can replace it with:
# ```python
# fig, ax = plt.subplots()
# ```

# %% [markdown]
# # EXERCIZE:

# %%
fig, axes = plt.subplots(figsize=plt.figaspect(.325),nrows=3, ncols=1)
x = np.linspace(0, 10, 100)
y1,y2,y3 = np.tan(x),np.cos(x+1),np.tan(x+2)
axes[0].set(title='Signal 1')
axes[1].set(title='Signal 2')
axes[2].set(title='Signal 3')
axes[0].plot(y1)
axes[1].plot(y2)
axes[2].plot(y3)
for ax in axes.flat:
    ax.set(xticks=[], yticks=[])
    
plt.show()
